# %% [markdown]
# ### Analytics Plan
# #### Step1:  Import Dataset and Prepare Data
#       Step1.1:Missing Value data check
#       Step1.2:Data Type check
#       Step1.3:Numarical data type check (range)
#       Step1.4:Categorical data type check
# #### Step2: Data Cleanning
# #### Step3: EDA
#        Step3.1: Numerical Features Analysis
#        Step3.2: Deal with the categorical Variables
# #### Step4: Prepard data for model building
#        Step4.1: Response variables -- Outliner Treatment
#        Step4.2: Numarical variables -- Multicollinearity Check
#        Step4.3: Categorical variables -- relative analysis and dummy variables
# #### Step5: Build linner regression modle
# #### Step6: Conduct factor important analysis

# %% [markdown]
# ### Step1: Import Dataset and Prepare Data

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np 
import pandas as pd 
# %matplotlib inline

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
from statsmodels.stats.outliers_influence import variance_inflation_factor #VIF Check

# check scikit-learn version
import sklearn
print(sklearn.__version__)
# Out:
# 0.19.1

# %% [markdown]
# ### Import Dataset

# %%
listings_raw = pd.read_csv('listings.csv', index_col = "id")

listings = listings_raw.copy()

# %%
listings.head()
# Out:
#                                     listing_url       scrape_id last_scraped  \
# id
# 12147973  https://www.airbnb.com/rooms/12147973  20160906204935   2016-09-07
# 3075044    https://www.airbnb.com/rooms/3075044  20160906204935   2016-09-07
# 6976          https://www.airbnb.com/rooms/6976  20160906204935   2016-09-07
# 1436513    https://www.airbnb.com/rooms/1436513  20160906204935   2016-09-07
# 7651065    https://www.airbnb.com/rooms/7651065  20160906204935   2016-09-07
#
#                                                    name  \
# id
# 12147973                     Sunny Bungalow in the City
# 3075044               Charming room in pet friendly apt
# 6976                   Mexican Folk Art Haven in Boston
# 1436513   Spacious Sunny Bedroom Suite in Historic Home
# 7651065                             Come Home to Boston
#
#                                                     summary  \
# id
# 12147973  Cozy, sunny, family home.  Master bedroom high...
# 3075044   Charming and quiet room in a second floor 1910...
# 6976      Come stay with a friendly, middle-aged guy in ...
# 1436513   Come experience the comforts of home away from...
# 7651065   My comfy, clean and relaxing home is one block...
#
#                                                       space  \
# id
# 12147973  The house has an open and cozy feel at the sam...
# 3075044   Small but cozy and quite room with a full size...
# 6976      Come stay with a friendly, middle-aged guy in ...
# 1436513   Most places you find in Boston are small howev...
# 7651065   Clean, attractive, private room, one block fro...
#
#                                                 description  \
# id
# 12147973  Cozy, sunny, family home.  Master bedroom high...
# 3075044   Charming and quiet room in a second floor 1910...
# 6976      Come stay with a friendly, middle-aged guy in ...
# 1436513   Come experience the comforts of home away from...
# 7651065   My comfy, clean and relaxing home is one block...
#
#          experiences_offered  \
# id
# 12147973                none
# 3075044                 none
# 6976                    none
# 1436513                 none
# 7651065                 none
#
#                                       neighborhood_overview  \
# id
# 12147973  Roslindale is quiet, convenient and friendly. ...
# 3075044   The room is in Roslindale, a diverse and prima...
# 6976      The LOCATION: Roslindale is a safe and diverse...
# 1436513   Roslindale is a lovely little neighborhood loc...
# 7651065   I love the proximity to downtown, the neighbor...
#
#                                                       notes        ...         \
# id                                                                 ...
# 12147973                                                NaN        ...
# 3075044   If you don't have a US cell phone, you can tex...        ...
# 6976      I am in a scenic part of Boston with a couple ...        ...
# 1436513   Please be mindful of the property as it is old...        ...
# 7651065   I have one roommate who lives on the lower lev...        ...
#
#          review_scores_value requires_license license jurisdiction_names  \
# id
# 12147973                 NaN                f     NaN                NaN
# 3075044                  9.0                f     NaN                NaN
# 6976                    10.0                f     NaN                NaN
# 1436513                 10.0                f     NaN                NaN
# 7651065                 10.0                f     NaN                NaN
#
#          instant_bookable cancellation_policy require_guest_profile_picture  \
# id
# 12147973                f            moderate                             f
# 3075044                 t            moderate                             f
# 6976                    f            moderate                             t
# 1436513                 f            moderate                             f
# 7651065                 f            flexible                             f
#
#          require_guest_phone_verification  calculated_host_listings_count  \
# id
# 12147973                                f                               1
# 3075044                                 f                               1
# 6976                                    f                               1
# 1436513                                 f                               1
# 7651065                                 f                               1
#
#          reviews_per_month
# id
# 12147973               NaN
# 3075044               1.30
# 6976                  0.47
# 1436513               1.00
# 7651065               2.25
#
# [5 rows x 94 columns]

# %% [markdown]
# ## Prepare Data

# %% [markdown]
# ### Rows:3585, Columns:94

# %%
num_rows = listings.shape[0] #Provide the number of rows in the dataset
num_cols = listings.shape[1] #Provide the number of columns in the dataset

# %%
num_rows
# Out:
# 3585

# %%
num_cols
# Out:
# 94

# %% [markdown]
# ### Step1.1: Missing Value data check
# #### 50 variables has no missing value

# %%
no_nulls = set(listings.columns[~listings.isnull().any()])
len(no_nulls)
# Out:
# 50

# %% [markdown]
# #### 9 Variables has more than half missing value

# %%
most_missing_cols = set(listings.columns[listings.isnull().mean() > 0.50])
most_missing_cols
# Out:
# {'has_availability',
#  'jurisdiction_names',
#  'license',
#  'monthly_price',
#  'neighbourhood_group_cleansed',
#  'notes',
#  'security_deposit',
#  'square_feet',
#  'weekly_price'}

# %% [markdown]
# ### Step1.2:Data Type check

# %%
# Summary:
#1. 4 varialbes have 0 non-null value (neighbourhood_group_cleansed,has_availability,license,jurisdiction_names)
#2. Some columns relative to $ need to change to number data tpye
#3. Some columns can be removed from the data like, listing_url,scrape_id,last_scraped
print(listings.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3585 entries, 12147973 to 14504422
# Data columns (total 94 columns):
# listing_url                         3585 non-null object
# scrape_id                           3585 non-null int64
# last_scraped                        3585 non-null object
# name                                3585 non-null object
# summary                             3442 non-null object
# space                               2528 non-null object
# description                         3585 non-null object
# experiences_offered                 3585 non-null object
# neighborhood_overview               2170 non-null object
# notes                               1610 non-null object
# transit                             2295 non-null object
# access                              2096 non-null object
# interaction                         2031 non-null object
# house_rules                         2393 non-null object
# thumbnail_url                       2986 non-null object
# medium_url                          2986 non-null object
# picture_url                         3585 non-null object
# xl_picture_url                      2986 non-null object
# host_id                             3585 non-null int64
# host_url                            3585 non-null object
# host_name                           3585 non-null object
# host_since                          3585 non-null object
# host_location                       3574 non-null object
# host_about                          2276 non-null object
# host_response_time                  3114 non-null object
# host_response_rate                  3114 non-null object
# host_acceptance_rate                3114 non-null object
# host_is_superhost                   3585 non-null object
# host_thumbnail_url                  3585 non-null object
# host_picture_url                    3585 non-null object
# host_neighbourhood                  3246 non-null object
# host_listings_count                 3585 non-null int64
# host_total_listings_count           3585 non-null int64
# host_verifications                  3585 non-null object
# host_has_profile_pic                3585 non-null object
# host_identity_verified              3585 non-null object
# street                              3585 non-null object
# neighbourhood                       3042 non-null object
# neighbourhood_cleansed              3585 non-null object
# neighbourhood_group_cleansed        0 non-null float64
# city                                3583 non-null object
# state                               3585 non-null object
# zipcode                             3547 non-null object
# market                              3571 non-null object
# smart_location                      3585 non-null object
# country_code                        3585 non-null object
# country                             3585 non-null object
# latitude                            3585 non-null float64
# longitude                           3585 non-null float64
# is_location_exact                   3585 non-null object
# property_type                       3582 non-null object
# room_type                           3585 non-null object
# accommodates                        3585 non-null int64
# bathrooms                           3571 non-null float64
# bedrooms                            3575 non-null float64
# beds                                3576 non-null float64
# bed_type                            3585 non-null object
# amenities                           3585 non-null object
# square_feet                         56 non-null float64
# price                               3585 non-null object
# weekly_price                        892 non-null object
# monthly_price                       888 non-null object
# security_deposit                    1342 non-null object
# cleaning_fee                        2478 non-null object
# guests_included                     3585 non-null int64
# extra_people                        3585 non-null object
# minimum_nights                      3585 non-null int64
# maximum_nights                      3585 non-null int64
# calendar_updated                    3585 non-null object
# has_availability                    0 non-null float64
# availability_30                     3585 non-null int64
# availability_60                     3585 non-null int64
# availability_90                     3585 non-null int64
# availability_365                    3585 non-null int64
# calendar_last_scraped               3585 non-null object
# number_of_reviews                   3585 non-null int64
# first_review                        2829 non-null object
# last_review                         2829 non-null object
# review_scores_rating                2772 non-null float64
# review_scores_accuracy              2762 non-null float64
# review_scores_cleanliness           2767 non-null float64
# review_scores_checkin               2765 non-null float64
# review_scores_communication         2767 non-null float64
# review_scores_location              2763 non-null float64
# review_scores_value                 2764 non-null float64
# requires_license                    3585 non-null object
# license                             0 non-null float64
# jurisdiction_names                  0 non-null float64
# instant_bookable                    3585 non-null object
# cancellation_policy                 3585 non-null object
# require_guest_profile_picture       3585 non-null object
# require_guest_phone_verification    3585 non-null object
# calculated_host_listings_count      3585 non-null int64
# reviews_per_month                   2829 non-null float64
# dtypes: float64(18), int64(14), object(62)
# memory usage: 2.6+ MB
# None

# %% [markdown]
# #### Step1.3:Numarical data type check ( Remember check the range)
# **1.** Variables scrape_id', 'host_id','jurisdiction_names'are not useful for model building
# **2.** Variables maximum_nights and availability_365 have high standard diviation which will afact the model accuracy.

# %%
num_vars = listings.select_dtypes(include=['float', 'int']).columns
num_vars
# Out:
# Index(['scrape_id', 'host_id', 'host_listings_count',
#        'host_total_listings_count', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'accommodates', 'bathrooms', 'bedrooms', 'beds',
#        'square_feet', 'guests_included', 'minimum_nights', 'maximum_nights',
#        'has_availability', 'availability_30', 'availability_60',
#        'availability_90', 'availability_365', 'number_of_reviews',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'jurisdiction_names',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype='object')

# %%
pd.set_option('display.max_columns', None)
listings.select_dtypes(include=['float', 'int']).describe()
# Out:
#           scrape_id       host_id  host_listings_count  \
# count  3.585000e+03  3.585000e+03          3585.000000
# mean   2.016091e+13  2.492311e+07            58.902371
# std    0.000000e+00  2.292781e+07           171.119663
# min    2.016091e+13  4.240000e+03             0.000000
# 25%    2.016091e+13  6.103425e+06             1.000000
# 50%    2.016091e+13  1.928100e+07             2.000000
# 75%    2.016091e+13  3.622147e+07             7.000000
# max    2.016091e+13  9.385411e+07           749.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed     latitude  \
# count                3585.000000                           0.0  3585.000000
# mean                   58.902371                           NaN    42.340032
# std                   171.119663                           NaN     0.024403
# min                     0.000000                           NaN    42.235942
# 25%                     1.000000                           NaN    42.329995
# 50%                     2.000000                           NaN    42.345201
# 75%                     7.000000                           NaN    42.354685
# max                   749.000000                           NaN    42.389982
#
#          longitude  accommodates    bathrooms     bedrooms         beds  \
# count  3585.000000   3585.000000  3571.000000  3575.000000  3576.000000
# mean    -71.084818      3.041283     1.221647     1.255944     1.609060
# std       0.031565      1.778929     0.501487     0.753060     1.011745
# min     -71.171789      1.000000     0.000000     0.000000     0.000000
# 25%     -71.105083      2.000000     1.000000     1.000000     1.000000
# 50%     -71.078429      2.000000     1.000000     1.000000     1.000000
# 75%     -71.062155      4.000000     1.000000     2.000000     2.000000
# max     -71.000100     16.000000     6.000000     5.000000    16.000000
#
#        square_feet  guests_included  minimum_nights  maximum_nights  \
# count    56.000000      3585.000000     3585.000000    3.585000e+03
# mean    858.464286         1.429847        3.171269    2.872584e+04
# std     608.874310         1.056787        8.874133    1.670136e+06
# min       0.000000         0.000000        1.000000    1.000000e+00
# 25%     415.000000         1.000000        1.000000    3.650000e+02
# 50%     825.000000         1.000000        2.000000    1.125000e+03
# 75%    1200.000000         1.000000        3.000000    1.125000e+03
# max    2400.000000        14.000000      300.000000    1.000000e+08
#
#        has_availability  availability_30  availability_60  availability_90  \
# count               0.0       3585.00000      3585.000000      3585.000000
# mean                NaN          8.64993        21.833194        38.558159
# std                 NaN         10.43533        21.860966        33.158272
# min                 NaN          0.00000         0.000000         0.000000
# 25%                 NaN          0.00000         0.000000         0.000000
# 50%                 NaN          4.00000        16.000000        37.000000
# 75%                 NaN         15.00000        40.000000        68.000000
# max                 NaN         30.00000        60.000000        90.000000
#
#        availability_365  number_of_reviews  review_scores_rating  \
# count       3585.000000        3585.000000           2772.000000
# mean         179.346444          19.044630             91.916667
# std          142.136180          35.571658              9.531686
# min            0.000000           0.000000             20.000000
# 25%           19.000000           1.000000             89.000000
# 50%          179.000000           5.000000             94.000000
# 75%          325.000000          21.000000             98.250000
# max          365.000000         404.000000            100.000000
#
#        review_scores_accuracy  review_scores_cleanliness  \
# count             2762.000000                2767.000000
# mean                 9.431571                   9.258041
# std                  0.931863                   1.168977
# min                  2.000000                   2.000000
# 25%                  9.000000                   9.000000
# 50%                 10.000000                  10.000000
# 75%                 10.000000                  10.000000
# max                 10.000000                  10.000000
#
#        review_scores_checkin  review_scores_communication  \
# count            2765.000000                  2767.000000
# mean                9.646293                     9.646549
# std                 0.762753                     0.735507
# min                 2.000000                     4.000000
# 25%                 9.000000                     9.000000
# 50%                10.000000                    10.000000
# 75%                10.000000                    10.000000
# max                10.000000                    10.000000
#
#        review_scores_location  review_scores_value  license  \
# count             2763.000000          2764.000000      0.0
# mean                 9.414043             9.168234      NaN
# std                  0.903436             1.011116      NaN
# min                  2.000000             2.000000      NaN
# 25%                  9.000000             9.000000      NaN
# 50%                 10.000000             9.000000      NaN
# 75%                 10.000000            10.000000      NaN
# max                 10.000000            10.000000      NaN
#
#        jurisdiction_names  calculated_host_listings_count  reviews_per_month
# count                 0.0                     3585.000000        2829.000000
# mean                  NaN                       12.733891           1.970908
# std                   NaN                       29.415076           2.120561
# min                   NaN                        1.000000           0.010000
# 25%                   NaN                        1.000000           0.480000
# 50%                   NaN                        2.000000           1.170000
# 75%                   NaN                        6.000000           2.720000
# max                   NaN                      136.000000          19.150000

# %% [markdown]
# #### Step1.4: Categorical data type check
# **1**. 'listing_url', 'last_scraped', 'name', 'summary', 'space',
#        'description', 'experiences_offered', 'neighborhood_overview', 'notes',
#        'transit', 'access', 'interaction', 'house_rules', 'thumbnail_url',
#        'medium_url', 'picture_url', 'xl_picture_url', 'host_url', 'host_name',
#        'host_since', 'host_location', 'host_about','state','market', 'smart_location', 'country_code', 'country','calendar_updated','calendar_last_scraped', 'first_review', 'last_review',
#        are not useful for model building
#
# **2**.'price', 'weekly_price', 'monthly_price','security_deposit', 'cleaning_fee'should be changed to float
#
# **3**. the number of items should be counted in 'amenities'and 'host_verifications'

# %%
cat_vars = listings.select_dtypes(include=['object']).columns
cat_vars
# Out:
# Index(['listing_url', 'last_scraped', 'name', 'summary', 'space',
#        'description', 'experiences_offered', 'neighborhood_overview', 'notes',
#        'transit', 'access', 'interaction', 'house_rules', 'thumbnail_url',
#        'medium_url', 'picture_url', 'xl_picture_url', 'host_url', 'host_name',
#        'host_since', 'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed', 'city', 'state',
#        'zipcode', 'market', 'smart_location', 'country_code', 'country',
#        'is_location_exact', 'property_type', 'room_type', 'bed_type',
#        'amenities', 'price', 'weekly_price', 'monthly_price',
#        'security_deposit', 'cleaning_fee', 'extra_people', 'calendar_updated',
#        'calendar_last_scraped', 'first_review', 'last_review',
#        'requires_license', 'instant_bookable', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification'],
#       dtype='object')

# %% [markdown]
# ### Step2: Data Cleanning

# %% [markdown]
# ####  Question 1: What's the difference between superhost and regular host? (How to analyze mutiple chosse question?)
# #### Question 1.1: Do super hosts respond faster than the regular host?

# %%
# Supperhost did respond faster than the regular host
response_time_superhost=pd.crosstab(listings.host_response_time, listings.host_is_superhost)
response_time_superhost/response_time_superhost.sum()
# Out:
# host_is_superhost          f         t
# host_response_time
# a few days or more  0.015855  0.000000
# within a day        0.160029  0.087065
# within a few hours  0.396755  0.353234
# within an hour      0.427360  0.559701

# %% [markdown]
# #### Internet is the most popular amenities, while wheelchair Accessible is provided by least of the house owner

# %%
# Check the options in the answer
listings['amenities'].value_counts()
# Out:
# {}                                                                                                                                                                                                                                                                                                                                                                                                                          32
# {TV,"Cable TV","Wireless Internet","Air Conditioning",Kitchen,Heating,Washer,Dryer,"translation missing: en.hosting_amenity_49","translation missing: en.hosting_amenity_50"}                                                                                                                                                                                                                                               15
# {TV,"Cable TV","Wireless Internet","Air Conditioning",Kitchen,Heating,Washer,Dryer,"Smoke Detector","Fire Extinguisher","translation missing: en.hosting_amenity_49","translation missing: en.hosting_amenity_50"}                                                                                                                                                                                                          14
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Kitchen,Gym,"Elevator in Building","Buzzer/Wireless Intercom",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                                                                            14
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Pool,Kitchen,Doorman,Gym,"Elevator in Building",Heating,"Family/Kid Friendly",Washer,Dryer,Essentials,Shampoo,"24-Hour Check-in","Hair Dryer",Iron}                                                                                                                                                                                                          11
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Kitchen,"Elevator in Building",Heating,"Family/Kid Friendly",Washer,Dryer,Essentials,Shampoo,"24-Hour Check-in","Hair Dryer",Iron}                                                                                                                                                                                                                            9
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Kitchen,Doorman,Gym,"Elevator in Building",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                                                                                                9
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Kitchen,"Pets Allowed",Heating,"Family/Kid Friendly","Smoke Detector","Carbon Monoxide Detector",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                                                                                                                                 8
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Kitchen,"Elevator in Building","Buzzer/Wireless Intercom",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                                                                                 8
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Kitchen,Doorman,Gym,"Elevator in Building",Heating,"Family/Kid Friendly",Washer,Dryer,Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron}                                                                                                                                                                                                        8
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Pool,Kitchen,"Pets Allowed",Doorman,Gym,"Elevator in Building",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","Fire Extinguisher",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                                                        7
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Pool,Kitchen,Doorman,Gym,"Elevator in Building",Heating,"Family/Kid Friendly",Washer,Dryer,Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron}                                                                                                                                                                                                   7
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Kitchen,"Free Parking on Premises",Gym,"Elevator in Building",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","Fire Extinguisher",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron}                                                                                                                     7
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Kitchen,"Buzzer/Wireless Intercom",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                                                                                                        7
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Kitchen,Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","Fire Extinguisher",Essentials}                                                                                                                                                                                                                                7
# {TV,"Cable TV","Wireless Internet","Air Conditioning",Kitchen,Heating,Washer,Dryer,"Smoke Detector","Fire Extinguisher"}                                                                                                                                                                                                                                                                                                     6
# {TV,Internet,"Wireless Internet","Air Conditioning",Kitchen,Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","Fire Extinguisher","Hair Dryer",Iron}                                                                                                                                                                                                                                    6
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Kitchen,"Buzzer/Wireless Intercom",Heating,Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","Fire Extinguisher",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                                                                                                          6
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Kitchen,Heating,Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                                                                                                                                                         6
# {TV,"Cable TV",Internet,"Wireless Internet",Kitchen,"Free Parking on Premises","Buzzer/Wireless Intercom",Heating,"Smoke Detector","Carbon Monoxide Detector","Fire Extinguisher",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                                                                                                               6
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Pool,Kitchen,Gym,"Elevator in Building","Buzzer/Wireless Intercom",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                                                                        6
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Kitchen,Heating,"Family/Kid Friendly","Smoke Detector","Carbon Monoxide Detector","Fire Extinguisher",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                                                                                                                            6
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Kitchen,Doorman,Gym,"Elevator in Building",Heating,"Family/Kid Friendly",Washer,Dryer,Essentials,Shampoo,"24-Hour Check-in",Iron}                                                                                                                                                                                                                             6
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Kitchen,"Elevator in Building",Heating,"Family/Kid Friendly","Smoke Detector","Carbon Monoxide Detector","First Aid Kit",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                                                                                                         5
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Kitchen,Gym,"Elevator in Building",Heating,"Family/Kid Friendly",Washer,Dryer,Essentials,Shampoo,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                                                                                                                                                                               5
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Kitchen,Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                                                                                                                                   5
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Pool,Kitchen,Doorman,Gym,"Elevator in Building",Heating,"Family/Kid Friendly",Washer,Dryer,Essentials,Shampoo,"translation missing: en.hosting_amenity_50"}                                                                                                                                                                                                   5
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Kitchen,Gym,"Indoor Fireplace",Heating,"Family/Kid Friendly",Washer,Dryer,Essentials,Shampoo,"translation missing: en.hosting_amenity_50"}                                                                                                                                                                                                                    5
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Kitchen,Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","Fire Extinguisher",Essentials,Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                                                                                                                                          5
# {TV,"Cable TV","Wireless Internet","Air Conditioning",Kitchen,Heating,Washer,Dryer}                                                                                                                                                                                                                                                                                                                                          5
#                                                                                                                                                                                                                                                                                                                                                                                                                             ..
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Kitchen,"Free Parking on Premises","Pets Allowed",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","First Aid Kit","Safety Card","Fire Extinguisher",Essentials,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                                               1
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Kitchen,Doorman,"Elevator in Building",Heating,Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector",Essentials,"translation missing: en.hosting_amenity_49","translation missing: en.hosting_amenity_50"}                                                                                                                                                 1
# {Internet,"Wireless Internet","Air Conditioning",Kitchen,Heating,"Smoke Detector","Carbon Monoxide Detector","Fire Extinguisher",Essentials}                                                                                                                                                                                                                                                                                 1
# {Internet,"Wireless Internet","Air Conditioning",Kitchen,Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","First Aid Kit","Safety Card","Fire Extinguisher",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                                                                                               1
# {TV,Internet,"Wireless Internet","Air Conditioning",Kitchen,"Free Parking on Premises",Gym,Breakfast,"Indoor Fireplace",Heating,Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","First Aid Kit","Safety Card","Fire Extinguisher",Essentials,Shampoo,Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                                                                         1
# {"Wireless Internet","Pets live on this property",Cat(s),Heating,Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                                                                                                                                                                                                                                1
# {Internet,"Wireless Internet",Kitchen,Heating,Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector",Essentials,Shampoo,"Lock on Bedroom Door",Hangers,"Laptop Friendly Workspace"}                                                                                                                                                                                                                                        1
# {Internet,"Wireless Internet","Air Conditioning",Kitchen,"Pets Allowed",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","Fire Extinguisher"}                                                                                                                                                                                                                                          1
# {Internet,"Wireless Internet",Kitchen,"Free Parking on Premises",Breakfast,Heating,Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","First Aid Kit","Fire Extinguisher",Essentials,Shampoo,Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                                                                                                                                    1
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning","Wheelchair Accessible",Kitchen,"Free Parking on Premises","Elevator in Building","Buzzer/Wireless Intercom",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","First Aid Kit","Fire Extinguisher",Essentials,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                             1
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Kitchen,Heating,Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron}                                                                                                                                                                                                                                                                              1
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning","Wheelchair Accessible",Pool,Kitchen,Doorman,Gym,"Pets live on this property",Cat(s),"Elevator in Building",Heating,"Family/Kid Friendly","Smoke Detector","Carbon Monoxide Detector","First Aid Kit","Safety Card","Fire Extinguisher",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                          1
# {TV,"Cable TV",Internet,"Wireless Internet","Wheelchair Accessible",Kitchen,"Free Parking on Premises","Pets live on this property","Other pet(s)","Elevator in Building","Buzzer/Wireless Intercom",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Fire Extinguisher",Essentials,Shampoo}                                                                                                                     1
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Gym,"Indoor Fireplace",Heating,"Family/Kid Friendly",Washer,Dryer,Essentials,Shampoo,"translation missing: en.hosting_amenity_50"}                                                                                                                                                                                                                            1
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Kitchen,Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","Fire Extinguisher",Essentials,"Hair Dryer",Iron}                                                                                                                                                                                                              1
# {TV,Internet,"Wireless Internet","Air Conditioning",Kitchen,"Buzzer/Wireless Intercom",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","First Aid Kit","Safety Card","Fire Extinguisher",Essentials,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                                                                         1
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Kitchen,"Free Parking on Premises","Buzzer/Wireless Intercom",Heating,Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","First Aid Kit","Fire Extinguisher",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace","translation missing: en.hosting_amenity_49","translation missing: en.hosting_amenity_50"}     1
# {"Wireless Internet","Air Conditioning",Kitchen,Heating,"Family/Kid Friendly",Essentials,Shampoo,Hangers,"translation missing: en.hosting_amenity_50"}                                                                                                                                                                                                                                                                       1
# {TV,Internet,"Wireless Internet","Air Conditioning",Kitchen,"Buzzer/Wireless Intercom",Heating,Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","Safety Card","Fire Extinguisher",Essentials,Shampoo}                                                                                                                                                                                                                1
# {Internet,"Wireless Internet","Air Conditioning",Kitchen,Heating,"Family/Kid Friendly",Essentials,Shampoo}                                                                                                                                                                                                                                                                                                                   1
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Kitchen,Doorman,"Elevator in Building","Indoor Fireplace","Buzzer/Wireless Intercom",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","Fire Extinguisher",Essentials,Shampoo,Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                                                     1
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning","Wheelchair Accessible",Kitchen,"Pets Allowed",Doorman,Gym,"Elevator in Building",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","Fire Extinguisher",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                                     1
# {"Cable TV","Wireless Internet","Air Conditioning",Kitchen,"Buzzer/Wireless Intercom",Heating,Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector"}                                                                                                                                                                                                                                                                      1
# {TV,"Air Conditioning",Kitchen,Gym,Heating,Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector",Essentials,Shampoo,"Hair Dryer"}                                                                                                                                                                                                                                                                                         1
# {"Wireless Internet","Air Conditioning",Kitchen,"Free Parking on Premises",Heating,Washer,Dryer,Essentials,Shampoo,Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                                                                                                                                                                                                                    1
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning","Wheelchair Accessible","Pets Allowed",Doorman,Heating,"Family/Kid Friendly",Essentials,Shampoo,Hangers,"Hair Dryer"}                                                                                                                                                                                                                                         1
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Kitchen,"Pets Allowed",Dog(s),Cat(s),"Other pet(s)","Elevator in Building",Heating,Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","First Aid Kit","Fire Extinguisher",Essentials,"24-Hour Check-in"}                                                                                                                                                1
# {TV,"Cable TV",Internet,"Wireless Internet",Kitchen,Heating,Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","First Aid Kit"}                                                                                                                                                                                                                                                                                        1
# {"Wireless Internet",Kitchen,Heating,Washer,Dryer,"Smoke Detector",Essentials,Shampoo,"Lock on Bedroom Door",Hangers,"Laptop Friendly Workspace","translation missing: en.hosting_amenity_49","translation missing: en.hosting_amenity_50"}                                                                                                                                                                                  1
# {TV,"Cable TV","Wireless Internet","Air Conditioning",Kitchen,"Indoor Fireplace","Buzzer/Wireless Intercom",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","Fire Extinguisher",Essentials,Shampoo}                                                                                                                                                                                                                 1
# Name: amenities, Length: 3092, dtype: int64

# %%
# Create a function to count the number of elements in one option
def total_count (df, col1, col2, look_for):
    '''
    INPUT:
    df - the pandas dataframe you want to search
    col1 - the column name you want to look through
    col2 - the column you want to count values from
    look_for - a list of strings you want to search for in each row of df[col]
    OUTPUT:
    new_df - a datafram of each look_for with the count of how often it shows up
    '''
    from collections import defaultdict
    new_df = defaultdict(int)
    for val in look_for:
        for idx in range (df.shape[0]):
            if val in df[col1][idx]:
                new_df[val]+= int(df[col2][idx])
    new_df = pd.DataFrame(pd.Series(new_df)).reset_index()
    new_df.columns =[col1,col2]
    new_df.sort_values('count',ascending= False, inplace= True)
    return new_df

# %%
def clean_and_plot(df,variable,title, plot=True):
    '''
    INPUT 
        df - a dataframe holding the CousinEducation column
        title - string the title of your plot
        axis - axis object
        plot - bool providing whether or not you want a plot back
        
    OUTPUT
        study_df - a dataframe with the count of how many individuals
        Displays a plot of pretty things related to the CousinEducation column.
    '''
    
    option_raw = df[variable].value_counts().reset_index()
    option_raw.rename(columns={'index': 'method', variable: 'count'}, inplace=True)
    option_new = total_count(option_raw, 'method', 'count', possible_vals)

    option_new.set_index('method', inplace=True)
    if plot:
        (option_new/df.shape[0]).plot(kind='bar', legend=None);
        plt.title(title);
        plt.show()
    props_df = option_new/df.shape[0]
    return props_df

# %%
possible_vals =["TV","Cable TV","Internet","Wireless Internet","Air Conditioning","Wheelchair Accessible",
                "Kitchen,Doorman","Elevator in Building","Buzzer/Wireless Intercom","Heating","Family/Kid Friendly",
                "Washer,Dryer","Smoke Detector","Carbon Monoxide Detector","First Aid Kit","Safety Card",
                "Fire Extinguisher","Essentials","Shampoo","24-Hour Check-in","Hangers","Hair Dryer",
                "Laptop Friendly Workspace"]

props_df = clean_and_plot(listings,'amenities','Amenities Distribution')

# %% [markdown]
# #### Question 1.2: Which amenities are more likely to be provided by the superhost vs. the regular host?
# If you choose Super host, you will be more likely to get Shampoo,First Aid Kit,Carbon Monoxide Detector than the none superhost

# %%
superhost_or_not=listings.host_is_superhost.value_counts()
superhost_or_not
# Out:
# f    3178
# t     407
# Name: host_is_superhost, dtype: int64

# %%
def superhost_or_not(formal_ed_str):

    if formal_ed_str in("t"):
        return (1)
    else:
        return (0)

listings["host_is_superhost"].apply(superhost_or_not)[:5] #Test your function to assure it provides 1 and 0 values for the df
# Out:
# id
# 12147973    0
# 3075044     0
# 6976        1
# 1436513     0
# 7651065     1
# Name: host_is_superhost, dtype: int64

# %%
listings['Superhost'] = listings["host_is_superhost"].apply(superhost_or_not)

# %%
ed_1 = listings[listings['Superhost']== 1] # Subset df to only those with HigherEd of 1
ed_0 = listings[listings['Superhost']== 0] # Subset df to only those with HigherEd of 0
print(ed_1['Superhost'][:5]) #Assure it looks like what you would expect
print(ed_0['Superhost'][:5]) #Assure it looks like what you would expect
# Out:
# id
# 6976        1
# 7651065     1
# 12386020    1
# 2843445     1
# 753446      1
# Name: Superhost, dtype: int64
# id
# 12147973    0
# 3075044     0
# 1436513     0
# 5706985     0
# 12023024    0
# Name: Superhost, dtype: int64

# %%
#Check your subset is correct - you should get a plot that was created using pandas styling
#which you can learn more about here: https://pandas.pydata.org/pandas-docs/stable/style.html

ed_1_perc = clean_and_plot(ed_1,'amenities','Superhost',plot=False)
ed_0_perc = clean_and_plot(ed_0,'amenities','Normal',plot=False)

comp_df = pd.merge(ed_1_perc, ed_0_perc, left_index=True, right_index=True)
comp_df.columns = ['Superhost', 'None-Superhost']
comp_df['Diff_HigherEd_Vals'] = comp_df['Superhost'] - comp_df['None-Superhost']
comp_df.style.bar(subset=['Diff_HigherEd_Vals'], align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_4bc1c03e_fe30_11eb_a21e_0242ac120002row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #5fba7d 37.5%, #5fba7d 44.8%, transparent 44.8%);
#         }    #T_4bc1c03e_fe30_11eb_a21e_0242ac120002row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #5fba7d 37.5%, #5fba7d 48.2%, transparent 48.2%);
#         }    #T_4bc1c03e_fe30_11eb_a21e_0242ac120002row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #5fba7d 37.5%, #5fba7d 49.2%, transparent 49.2%);
#         }    #T_4bc1c03e_fe30_11eb_a21e_0242ac120002row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #5fba7d 37.5%, #5fba7d 70.7%, transparent 70.7%);
#         }    #T_4bc1c03e_fe30_11eb_a21e_0242ac120002row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #5fba7d 37.5%, #5fba7d 74.9%, transparent 74.9%);
#         }    #T_4bc1c03e_fe30_11eb_a21e_0242ac120002row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #5fba7d 37.5%, #5fba7d 99.1%, transparent 99.1%);
#         }    #T_4bc1c03e_fe30_11eb_a21e_0242ac120002row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #5fba7d 37.5%, #5fba7d 62.5%, transparent 62.5%);
#         }    #T_4bc1c03e_fe30_11eb_a21e_0242ac120002row7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #5fba7d 37.5%, #5fba7d 89.3%, transparent 89.3%);
#         }    #T_4bc1c03e_fe30_11eb_a21e_0242ac120002row8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #5fba7d 37.5%, #5fba7d 38.8%, transparent 38.8%);
#         }    #T_4bc1c03e_fe30_11eb_a21e_0242ac120002row9_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #5fba7d 37.5%, #5fba7d 55.8%, transparent 55.8%);
#         }    #T_4bc1c03e_fe30_11eb_a21e_0242ac120002row10_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #5fba7d 37.5%, #5fba7d 79.0%, transparent 79.0%);
#         }    #T_4bc1c03e_fe30_11eb_a21e_0242ac120002row11_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #5fba7d 37.5%, #5fba7d 88.2%, transparent 88.2%);
#         }    #T_4bc1c03e_fe30_11eb_a21e_0242ac120002row12_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #5fba7d 37.5%, #5fba7d 91.4%, transparent 91.4%);
#         }    #T_4bc1c03e_fe30_11eb_a21e_0242ac120002row13_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #5fba7d 37.5%, #5fba7d 64.9%, transparent 64.9%);
#         }    #T_4bc1c03e_fe30_11eb_a21e_0242ac120002row14_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #5fba7d 37.5%, #5fba7d 53.3%, transparent 53.3%);
#         }    #T_4bc1c03e_fe30_11eb_a21e_0242ac120002row15_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #5fba7d 37.5%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_4bc1c03e_fe30_11eb_a21e_0242ac120002row16_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #5fba7d 37.5%, #5fba7d 82.7%, transparent 82.7%);
#         }    #T_4bc1c03e_fe30_11eb_a21e_0242ac120002row17_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 15.1%, #d65f5f 15.1%, #d65f5f 37.5%, transparent 37.5%);
#         }    #T_4bc1c03e_fe30_11eb_a21e_0242ac120002row18_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #5fba7d 37.5%, #5fba7d 57.8%, transparent 57.8%);
#         }    #T_4bc1c03e_fe30_11eb_a21e_0242ac120002row19_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #5fba7d 37.5%, #5fba7d 65.9%, transparent 65.9%);
#         }    #T_4bc1c03e_fe30_11eb_a21e_0242ac120002row20_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent -0.0%, #d65f5f -0.0%, #d65f5f 37.5%, transparent 37.5%);
#         }    #T_4bc1c03e_fe30_11eb_a21e_0242ac120002row21_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 31.0%, #d65f5f 31.0%, #d65f5f 37.5%, transparent 37.5%);
#         }    #T_4bc1c03e_fe30_11eb_a21e_0242ac120002row22_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.9%, #d65f5f 32.9%, #d65f5f 37.5%, transparent 37.5%);
#         }</style>
# <table id="T_4bc1c03e_fe30_11eb_a21e_0242ac120002" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Superhost</th>
#         <th class="col_heading level0 col1" >None-Superhost</th>
#         <th class="col_heading level0 col2" >Diff_HigherEd_Vals</th>
#     </tr>    <tr>
#         <th class="index_name level0" >method</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_4bc1c03e_fe30_11eb_a21e_0242ac120002level0_row0" class="row_heading level0 row0" >Internet</th>
#         <td id="T_4bc1c03e_fe30_11eb_a21e_0242ac120002row0_col0" class="data row0 col0" >0.987715</td>
#         <td id="T_4bc1c03e_fe30_11eb_a21e_0242ac120002row0_col1" class="data row0 col1" >0.961926</td>
#         <td id="T_4bc1c03e_fe30_11eb_a21e_0242ac120002row0_col2" class="data row0 col2" >0.0257892</td>
#     </tr>    <tr>
#         <th id="T_4bc1c03e_fe30_11eb_a21e_0242ac120002level0_row1" class="row_heading level0 row1" >Wireless Internet</th>
#         <td id="T_4bc1c03e_fe30_11eb_a21e_0242ac120002row1_col0" class="data row1 col0" >0.987715</td>
#         <td id="T_4bc1c03e_fe30_11eb_a21e_0242ac120002row1_col1" class="data row1 col1" >0.949969</td>
#         <td id="T_4bc1c03e_fe30_11eb_a21e_0242ac120002row1_col2" class="data row1 col2" >0.0377465</td>
#     </tr>    <tr>
#         <th id="T_4bc1c03e_fe30_11eb_a21e_0242ac120002level0_row2" class="row_heading level0 row2" >Heating</th>
#         <td id="T_4bc1c03e_fe30_11eb_a21e_0242ac120002row2_col0" class="data row2 col0" >0.980344</td>
#         <td id="T_4bc1c03e_fe30_11eb_a21e_0242ac120002row2_col1" class="data row2 col1" >0.93927</td>
#         <td id="T_4bc1c03e_fe30_11eb_a21e_0242ac120002row2_col2" class="data row2 col2" >0.041074</td>
#     </tr>    <tr>
#         <th id="T_4bc1c03e_fe30_11eb_a21e_0242ac120002level0_row3" class="row_heading level0 row3" >Essentials</th>
#         <td id="T_4bc1c03e_fe30_11eb_a21e_0242ac120002row3_col0" class="data row3 col0" >0.938575</td>
#         <td id="T_4bc1c03e_fe30_11eb_a21e_0242ac120002row3_col1" class="data row3 col1" >0.821901</td>

# %% [markdown]
# #### Question 1.3: Do the superhosts' review score is higher than the none superhost?

# %%
listings.groupby("Superhost", as_index=True)['review_scores_rating','review_scores_accuracy','review_scores_checkin', 
                                       'review_scores_cleanliness','review_scores_checkin','review_scores_communication',
                                       'review_scores_location','review_scores_value'].mean()
# Out:
#            review_scores_rating  review_scores_accuracy  \
# Superhost
# 0                     91.061817                9.353314
# 1                     97.076142                9.903308
#
#            review_scores_checkin  review_scores_cleanliness  \
# Superhost
# 0                       9.595529                   9.162663
# 1                       9.951777                   9.832487
#
#            review_scores_checkin  review_scores_communication  \
# Superhost
# 0                       9.595529                     9.594185
# 1                       9.951777                     9.961929
#
#            review_scores_location  review_scores_value
# Superhost
# 0                        9.380751             9.076371
# 1                        9.614213             9.720812

# %% [markdown]
# #### Question 2: Is there any bias between the house or other house tpye among the Amenity type ?
# If you choose house, you are more likely to have TV, Cable TV, Family/Kid Friendly

# %%
room_type=listings.room_type.value_counts()
room_type
# Out:
# Entire home/apt    2127
# Private room       1378
# Shared room          80
# Name: room_type, dtype: int64

# %%
def house (formal_ed_str):

    if formal_ed_str in("Entire home/apt"):
        return (1)
    else:
        return (0)

listings["room_type"].apply(house)[:5] #Test your function to assure it provides 1 and 0 values for the df
# Out:
# id
# 12147973    1
# 3075044     0
# 6976        0
# 1436513     0
# 7651065     0
# Name: room_type, dtype: int64

# %%
listings['house_or_not'] = listings["room_type"].apply(house)

# %%
ed_house = listings[listings['house_or_not']== 1] # Subset df to only those with HigherEd of 1
ed_not_house = listings[listings['house_or_not']== 0] # Subset df to only those with HigherEd of 0
print(ed_house['house_or_not'][:5]) #Assure it looks like what you would expect
print(ed_not_house['house_or_not'][:5]) #Assure it looks like what you would expect
# Out:
# id
# 12147973    1
# 5706985     1
# 849408      1
# 2684840     1
# 13547301    1
# Name: house_or_not, dtype: int64
# id
# 3075044     0
# 6976        0
# 1436513     0
# 7651065     0
# 12386020    0
# Name: house_or_not, dtype: int64

# %%
#Check your subset is correct - you should get a plot that was created using pandas styling
#which you can learn more about here: https://pandas.pydata.org/pandas-docs/stable/style.html

ed_1_perc = clean_and_plot(ed_house,'amenities', 'House', plot=False)
ed_0_perc = clean_and_plot(ed_not_house,'amenities', 'Other', plot=False)

comp_df = pd.merge(ed_1_perc, ed_0_perc, left_index=True, right_index=True)
comp_df.columns = ['House', 'Others']
comp_df['Diff_HigherEd_Vals'] = comp_df['House'] - comp_df['Others']
comp_df.style.bar(subset=['Diff_HigherEd_Vals'], align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_6d1c5a14_fe30_11eb_a21e_0242ac120002row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.0%, #5fba7d 33.0%, #5fba7d 37.1%, transparent 37.1%);
#         }    #T_6d1c5a14_fe30_11eb_a21e_0242ac120002row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.0%, #5fba7d 33.0%, #5fba7d 44.7%, transparent 44.7%);
#         }    #T_6d1c5a14_fe30_11eb_a21e_0242ac120002row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.0%, #5fba7d 33.0%, #5fba7d 37.0%, transparent 37.0%);
#         }    #T_6d1c5a14_fe30_11eb_a21e_0242ac120002row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.0%, #5fba7d 33.0%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_6d1c5a14_fe30_11eb_a21e_0242ac120002row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.0%, #5fba7d 33.0%, #5fba7d 80.0%, transparent 80.0%);
#         }    #T_6d1c5a14_fe30_11eb_a21e_0242ac120002row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.0%, #5fba7d 33.0%, #5fba7d 44.8%, transparent 44.8%);
#         }    #T_6d1c5a14_fe30_11eb_a21e_0242ac120002row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 30.1%, #d65f5f 30.1%, #d65f5f 33.0%, transparent 33.0%);
#         }    #T_6d1c5a14_fe30_11eb_a21e_0242ac120002row7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.0%, #5fba7d 33.0%, #5fba7d 51.0%, transparent 51.0%);
#         }    #T_6d1c5a14_fe30_11eb_a21e_0242ac120002row8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.0%, #5fba7d 33.0%, #5fba7d 48.4%, transparent 48.4%);
#         }    #T_6d1c5a14_fe30_11eb_a21e_0242ac120002row9_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 30.2%, #d65f5f 30.2%, #d65f5f 33.0%, transparent 33.0%);
#         }    #T_6d1c5a14_fe30_11eb_a21e_0242ac120002row10_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.0%, #5fba7d 33.0%, #5fba7d 98.7%, transparent 98.7%);
#         }    #T_6d1c5a14_fe30_11eb_a21e_0242ac120002row11_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.0%, #5fba7d 33.0%, #5fba7d 99.4%, transparent 99.4%);
#         }    #T_6d1c5a14_fe30_11eb_a21e_0242ac120002row12_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.0%, #5fba7d 33.0%, #5fba7d 44.9%, transparent 44.9%);
#         }    #T_6d1c5a14_fe30_11eb_a21e_0242ac120002row13_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.0%, #5fba7d 33.0%, #5fba7d 60.7%, transparent 60.7%);
#         }    #T_6d1c5a14_fe30_11eb_a21e_0242ac120002row14_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.0%, #5fba7d 33.0%, #5fba7d 45.8%, transparent 45.8%);
#         }    #T_6d1c5a14_fe30_11eb_a21e_0242ac120002row15_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.0%, #5fba7d 33.0%, #5fba7d 36.0%, transparent 36.0%);
#         }    #T_6d1c5a14_fe30_11eb_a21e_0242ac120002row16_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.0%, #5fba7d 33.0%, #5fba7d 72.9%, transparent 72.9%);
#         }    #T_6d1c5a14_fe30_11eb_a21e_0242ac120002row17_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.0%, #5fba7d 33.0%, #5fba7d 79.7%, transparent 79.7%);
#         }    #T_6d1c5a14_fe30_11eb_a21e_0242ac120002row18_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.0%, #5fba7d 33.0%, #5fba7d 52.2%, transparent 52.2%);
#         }    #T_6d1c5a14_fe30_11eb_a21e_0242ac120002row19_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #d65f5f 0.0%, #d65f5f 33.0%, transparent 33.0%);
#         }    #T_6d1c5a14_fe30_11eb_a21e_0242ac120002row20_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 26.6%, #d65f5f 26.6%, #d65f5f 33.0%, transparent 33.0%);
#         }    #T_6d1c5a14_fe30_11eb_a21e_0242ac120002row21_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.0%, #5fba7d 33.0%, #5fba7d 46.7%, transparent 46.7%);
#         }    #T_6d1c5a14_fe30_11eb_a21e_0242ac120002row22_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.0%, #5fba7d 33.0%, #5fba7d 39.1%, transparent 39.1%);
#         }</style>
# <table id="T_6d1c5a14_fe30_11eb_a21e_0242ac120002" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >House</th>
#         <th class="col_heading level0 col1" >Others</th>
#         <th class="col_heading level0 col2" >Diff_HigherEd_Vals</th>
#     </tr>    <tr>
#         <th class="index_name level0" >method</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_6d1c5a14_fe30_11eb_a21e_0242ac120002level0_row0" class="row_heading level0 row0" >Internet</th>
#         <td id="T_6d1c5a14_fe30_11eb_a21e_0242ac120002row0_col0" class="data row0 col0" >0.972732</td>
#         <td id="T_6d1c5a14_fe30_11eb_a21e_0242ac120002row0_col1" class="data row0 col1" >0.953361</td>
#         <td id="T_6d1c5a14_fe30_11eb_a21e_0242ac120002row0_col2" class="data row0 col2" >0.0193708</td>
#     </tr>    <tr>
#         <th id="T_6d1c5a14_fe30_11eb_a21e_0242ac120002level0_row1" class="row_heading level0 row1" >Heating</th>
#         <td id="T_6d1c5a14_fe30_11eb_a21e_0242ac120002row1_col0" class="data row1 col0" >0.96662</td>
#         <td id="T_6d1c5a14_fe30_11eb_a21e_0242ac120002row1_col1" class="data row1 col1" >0.910837</td>
#         <td id="T_6d1c5a14_fe30_11eb_a21e_0242ac120002row1_col2" class="data row1 col2" >0.0557829</td>
#     </tr>    <tr>
#         <th id="T_6d1c5a14_fe30_11eb_a21e_0242ac120002level0_row2" class="row_heading level0 row2" >Wireless Internet</th>
#         <td id="T_6d1c5a14_fe30_11eb_a21e_0242ac120002row2_col0" class="data row2 col0" >0.961918</td>
#         <td id="T_6d1c5a14_fe30_11eb_a21e_0242ac120002row2_col1" class="data row2 col1" >0.943073</td>
#         <td id="T_6d1c5a14_fe30_11eb_a21e_0242ac120002row2_col2" class="data row2 col2" >0.0188455</td>
#     </tr>    <tr>
#         <th id="T_6d1c5a14_fe30_11eb_a21e_0242ac120002level0_row3" class="row_heading level0 row3" >TV</th>
#         <td id="T_6d1c5a14_fe30_11eb_a21e_0242ac120002row3_col0" class="data row3 col0" >0.890456</td>
#         <td id="T_6d1c5a14_fe30_11eb_a21e_0242ac120002row3_col1" class="data row3 col1" >0.569959</td>
#         <td id="T_6d1c5a14_fe

# %% [markdown]
# ### Data Cleanning_make the funtion resusable
# **1**. Delete the variables have no help in model building
#
# **2**. Delete the variables have all null value and missing value more than 50%
#
# **3**. Change'price', 'weekly_price', 'monthly_price','security_deposit', 'cleaning_fee'into float data tpye
#
# **4**. Count how many days since the date
#
# **5**. Count the items in'amenities'and 'host_verifications'
#
# **6**. Fill the numarical missing value with mean

# %%
def clean_dataset (df, no_usage,response_variable,Money_Variable,Transfer_Variables,Time_Length,till_date,count_items):
    #1 Delete the variables have no help in model building
    drop_no_usage= df.drop(no_usage, axis=1) 

    #1.1 drop the rows has missing value in the respones variable
    MissY_drop = drop_no_usage.dropna(subset=[response_variable],axis=0) 

    #1.2 delete the cloumns have missing value more than 0.5
    nan_cols = MissY_drop.columns[MissY_drop.isnull().mean() > 0.50]
    df_dropna = MissY_drop.drop(nan_cols, axis=1) 

    #3.1 Change $  into float
    for col in Money_Variable:
        # remove $ and comma from price, ignore na values so that we wont get any errors.
        df_dropna[col] = df_dropna[col].map(lambda p : p.replace('$','').replace(',',''), na_action='ignore')
        # convert cols to float type
        df_dropna[col] = df_dropna[col].astype(float)

    #3.2 Change %  into float
    for col in Transfer_Variables:
        df_dropna[col] = df_dropna[col].str.extract(r'(\d+)')
        df_dropna[col] = df_dropna[col].astype('float')
        
    #4. Count how many days since the date
    df_dropna[Time_Length] = pd.to_datetime(df_dropna[Time_Length])
    temp = pd.to_datetime(till_date)

    df_dropna['host_len'] = df_dropna.host_since.apply(lambda x: pd.Timedelta(temp-x).days)
    df_dropna = df_dropna.drop(Time_Length, axis=1)

    #5. Extract the number of item in one cell
    for col in count_items:
        df_dropna[col] = df_dropna[col].apply(lambda x: len(x.replace('{', '').\
                        replace('{', '').replace('"', '').split(',')))
  
    #6. fill numarical missing value with mean
    num_vars = df_dropna.select_dtypes(include=['float', 'int']).columns
    for col in num_vars:
        df_dropna[col].fillna((df_dropna[col].mean()), inplace=True)
        
    x=df_dropna
    return x

# %%
no_usage= ['scrape_id', 'host_id','listing_url', 'last_scraped', 'name', 'summary', 'space', 
           'description', 'experiences_offered', 'neighborhood_overview', 'transit', 'access', 'interaction', 
           'house_rules', 'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url', 'host_url', 'host_name', 
           'host_location', 'host_about','state','market', 'smart_location', 'country_code', 'country',
           'calendar_updated','calendar_last_scraped', 'first_review', 'last_review','host_thumbnail_url', 'host_picture_url']

response_variable = 'price'

Money_Variable = ["cleaning_fee", "price", "extra_people"]

Transfer_Variables= ['host_response_rate', 'host_acceptance_rate']

Time_Length='host_since'

till_date='08/03/2021'

count_items=['amenities','host_verifications']


x1=clean_dataset (listings,no_usage, response_variable, Money_Variable,Transfer_Variables,Time_Length,till_date,count_items)

# %%
x1.head()
# Out:
#           host_response_time  host_response_rate  host_acceptance_rate  \
# id
# 12147973                 NaN           94.989082             84.173089
# 3075044       within an hour          100.000000            100.000000
# 6976      within a few hours          100.000000             88.000000
# 1436513   within a few hours          100.000000             50.000000
# 7651065       within an hour          100.000000            100.000000
#
#          host_is_superhost host_neighbourhood  host_listings_count  \
# id
# 12147973                 f         Roslindale                    1
# 3075044                  f         Roslindale                    1
# 6976                     t         Roslindale                    1
# 1436513                  f                NaN                    1
# 7651065                  t         Roslindale                    1
#
#           host_total_listings_count  host_verifications host_has_profile_pic  \
# id
# 12147973                          1                   4                    t
# 3075044                           1                   7                    t
# 6976                              1                   4                    t
# 1436513                           1                   3                    t
# 7651065                           1                   4                    t
#
#          host_identity_verified  \
# id
# 12147973                      f
# 3075044                       t
# 6976                          t
# 1436513                       f
# 7651065                       t
#
#                                                      street neighbourhood  \
# id
# 12147973      Birch Street, Boston, MA 02131, United States    Roslindale
# 3075044   Pinehurst Street, Boston, MA 02131, United States    Roslindale
# 6976            Ardale St., Boston, MA 02131, United States    Roslindale
# 1436513                           Boston, MA, United States           NaN
# 7651065     Durnell Avenue, Boston, MA 02131, United States    Roslindale
#
#          neighbourhood_cleansed    city zipcode   latitude  longitude  \
# id
# 12147973             Roslindale  Boston   02131  42.282619 -71.133068
# 3075044              Roslindale  Boston   02131  42.286241 -71.134374
# 6976                 Roslindale  Boston   02131  42.292438 -71.135765
# 1436513              Roslindale  Boston     NaN  42.281106 -71.121021
# 7651065              Roslindale  Boston   02131  42.284512 -71.136258
#
#          is_location_exact property_type        room_type  accommodates  \
# id
# 12147973                 t         House  Entire home/apt             4
# 3075044                  t     Apartment     Private room             2
# 6976                     t     Apartment     Private room             2
# 1436513                  f         House     Private room             4
# 7651065                  t         House     Private room             2
#
#           bathrooms  bedrooms  beds  bed_type  amenities  price  cleaning_fee  \
# id
# 12147973        1.5       2.0   3.0  Real Bed         15  250.0     35.000000
# 3075044         1.0       1.0   1.0  Real Bed         21   65.0     10.000000
# 6976            1.0       1.0   1.0  Real Bed         18   65.0     68.380145
# 1436513         1.0       1.0   2.0  Real Bed         23   75.0     50.000000
# 7651065         1.5       1.0   2.0  Real Bed         14   79.0     15.000000
#
#           guests_included  extra_people  minimum_nights  maximum_nights  \
# id
# 12147973                1           0.0               2            1125
# 3075044                 0           0.0               2              15
# 6976                    1          20.0               3              45
# 1436513                 2          25.0               1            1125
# 7651065                 1           0.0               2              31
#
#           availability_30  availability_60  availability_90  availability_365  \
# id
# 12147973                0                0                0                 0
# 3075044                26               54               84               359
# 6976                   19               46               61               319
# 1436513                 6               16               26                98
# 7651065                13               34               59               334
#
#           number_of_reviews  review_scores_rating  review_scores_accuracy  \
# id
# 12147973                  0             91.916667                9.431571
# 3075044                  36             94.000000               10.000000
# 6976                     41             98.000000               10.000000
# 1436513                   1            100.000000               10.000000
# 7651065                  29             99.000000               10.000000
#
#           review_scores_cleanliness  review_scores_checkin  \
# id
# 12147973                   9.258041               9.646293
# 3075044                    9.000000              10.000000
# 6976                       9.000000              10.000000
# 1436513                   10.000000              10.000000
# 7651065                   10.000000              10.000000
#
#           review_scores_communication  review_scores_location  \
# id
# 12147973                     9.646549                9.414043
# 3075044                     10.000000                9.000000
# 6976                        10.000000                9.000000
# 1436513                     10.000000               10.000000
# 7651065                     10.000000                9.000000
#
#           review_scores_value requires_license instant_bookable  \
# id
# 12147973             9.168234                f                f
# 3075044              9.000000                f                t
# 6976                10.000000                f                f
# 1436513             10.000000                f                f
# 7651065             10.000000                f                f
#
#          cancellation_policy require_guest_profile_picture  \
# id
# 12147973            moderate                             f
# 3075044             moderate                             f
# 6976                moderate                             t
# 1436513             moderate                             f
# 7651065             flexible                             f
#
#          require_guest_phone_verification  calculated_host_listings_count  \
# id
# 12147973                                f                               1
# 3075044                                 f                               1
# 6976                                    f                               1
# 1436513                                 f                               1
# 7651065                                 f                               1
#
#           reviews_per_month  Superhost  house_or_not  host_len
# id
# 12147973           1.970908          0             1      2302
# 3075044            1.300000          0             0      3344
# 6976               0.470000          1             0      4467
# 1436513            1.000000          0             0      3026
# 7651065            2.250000          1             0      2641

# %% [markdown]
# #### Question3: What's the top 10 expensive neighbourhood?
# Downtown,Beacon Hill,Back Bay,South End,North End,South Boston Waterfront,Leather District,South Boston,West End,Fenway is the top 10 expensive neighbourhood

# %%
x1.groupby(['neighbourhood_cleansed']).mean()['price'].sort_values()
# Out:
# neighbourhood_cleansed
# Mattapan                    75.125000
# Hyde Park                   86.548387
# Dorchester                  91.639405
# Roslindale                  98.428571
# West Roxbury               107.108696
# Allston                    112.307692
# Brighton                   118.767568
# East Boston                119.153333
# Mission Hill               121.967742
# Longwood Medical Area      138.444444
# Jamaica Plain              138.478134
# Roxbury                    146.333333
# South Boston               187.609195
# North End                  195.678322
# Charlestown                198.045045
# South End                  204.349693
# West End                   209.591837
# Fenway                     220.393103
# Beacon Hill                224.443299
# Chinatown                  232.352113
# Downtown                   236.459302
# Back Bay                   240.950331
# Leather District           253.600000
# Bay Village                266.833333
# South Boston Waterfront    306.060241
# Name: price, dtype: float64

# %% [markdown]
# ### Step3: EDA
# #### Step3.1:Numerical Features Analysis

# %% [markdown]
# #### Correlation matrix Summary
# **1**. accommodates,beds,bedrooms,cleaning_fee are high correlative with price
#
# **2**. avaliability_30,60,90, host_listing count,host_total_listing count are highly correlative
#
# **3**. accommodateds are highlly correlative with beds,bedrooms,bathroom,cleening fee, gust_inluded
#
# **4**. guest include is highly correlative with extra_people
#
# **5**. number of review is highly correlative with reviews per month
#
# **6**. review relative variables are highly corelative.

# %%
corrlation = x1.select_dtypes(include=['int64', 'float64']).corr()
mask = np.zeros_like(corrlation)
mask[np.triu_indices_from(mask)] = True
plt.figure(figsize=(24,12))
plt.title('Heatmap of corr of features')
sns.heatmap(corrlation, mask = mask, vmax=.3, square=True, annot=True, fmt='.2f', cmap='coolwarm')
plt.show()

# %% [markdown]
# #### Step3.2: Deal with the categorical Variables

# %%
# Check the categorical variables again
x1.select_dtypes(include=['object']).columns
# Out:
# Index(['host_response_time', 'host_is_superhost', 'host_neighbourhood',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed', 'city', 'zipcode',
#        'is_location_exact', 'property_type', 'room_type', 'bed_type',
#        'requires_license', 'instant_bookable', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification'],
#       dtype='object')

# %% [markdown]
# #### More than 40% have strict cancellation policy

# %%
cancellation_policy_count=x1.cancellation_policy.value_counts()
(cancellation_policy_count/x1.shape[0]).plot(kind="bar");
plt.title("cancellation_policy_count");

# %% [markdown]
# #### Step3.2 Choose Categorical Variable

# %% [markdown]
# #### The price among neighbourhood ,property_type, room_type,require_guest_phone_verification,bed_type have obvious price difference

# %%
x1.groupby(['zipcode']).mean()['price'].sort_values().dropna()
# Out:
# zipcode
# 02169           25.000000
# 02186           50.000000
# 02472           60.000000
# 02134-1704      80.000000
# 02467           80.400000
# 02126           80.958333
# 02124           81.200000
# 02163           86.666667
# 02136           88.793103
# 02145           89.833333
# 02445           92.800000
# 02125           95.527132
# 02143           95.571429
# 02131           96.907692
# 02121          101.310345
# 02132          103.783784
# 02134          108.836207
# 02122          114.409091
# 02128          119.684932
# 02135          120.395349
# 02119          126.110000
# 02120          126.173913
# 02130          138.746224
# 02141          150.000000
# 02218          169.000000
# 02446          178.500000
# 02127          189.938889
# 02113          190.158416
# 02139          190.166667
# 02115          195.065089
# 02114          213.238095
# 02118          217.789474
# 02138          221.500000
# 02129          221.844444
# 02215          225.546610
# 02116          229.180412
# 02108          230.361111
# 02109          238.941176
# 02111          253.535354
# 02142          270.000000
# 02110          274.076923
# 02210          313.440000
# 02108 02111    334.000000
# Name: price, dtype: float64

# %%
x1.groupby(['is_location_exact']).mean()['price'].sort_values().dropna()
# Out:
# is_location_exact
# f    149.609901
# t    177.912662
# Name: price, dtype: float64

# %%
x1.groupby(['property_type']).mean()['price'].sort_values().dropna()
# Out:
# property_type
# Camper/RV           60.000000
# Dorm                62.500000
# Entire Floor       122.000000
# Bed & Breakfast    129.365854
# House              131.599644
# Townhouse          149.037037
# Apartment          181.966692
# Loft               185.410256
# Villa              189.500000
# Condominium        190.246753
# Other              229.941176
# Boat               268.833333
# Guesthouse         289.000000
# Name: price, dtype: float64

# %%
x1.groupby(['room_type']).mean()['price'].sort_values().dropna()
# Out:
# room_type
# Shared room         92.762500
# Private room        96.041364
# Entire home/apt    227.436765
# Name: price, dtype: float64

# %%
x1.groupby(['requires_license']).mean()['price'].sort_values().dropna()
# Out:
# requires_license
# f    173.925802
# Name: price, dtype: float64

# %%
x1.groupby(['instant_bookable']).mean()['price'].sort_values().dropna()
# Out:
# instant_bookable
# t    154.836700
# f    177.716817
# Name: price, dtype: float64

# %%
x1.groupby(['cancellation_policy']).mean()['price'].sort_values().dropna()
# Out:
# cancellation_policy
# flexible           148.908909
# moderate           162.620239
# strict             188.219975
# super_strict_30    324.141176
# Name: price, dtype: float64

# %%
x1.groupby(['require_guest_profile_picture']).mean()['price'].sort_values().dropna()
# Out:
# require_guest_profile_picture
# t    158.552239
# f    174.218590
# Name: price, dtype: float64

# %%
x1.groupby(['require_guest_phone_verification']).mean()['price'].sort_values().dropna()
# Out:
# require_guest_phone_verification
# f    168.601553
# t    249.139241
# Name: price, dtype: float64

# %%
x1.groupby(['host_is_superhost']).mean()['price'].sort_values().dropna()
# Out:
# host_is_superhost
# f    173.604468
# t    176.434889
# Name: price, dtype: float64

# %%
x1.groupby(['host_response_time']).mean()['price'].sort_values().dropna()
# Out:
# host_response_time
# a few days or more    150.627907
# within a day          155.127932
# within an hour        160.638728
# within a few hours    190.050082
# Name: price, dtype: float64

# %%
x1.groupby(['host_has_profile_pic']).mean()['price'].sort_values().dropna()
# Out:
# host_has_profile_pic
# f    171.125000
# t    173.932066
# Name: price, dtype: float64

# %%
x1.groupby(['host_identity_verified']).mean()['price'].sort_values().dropna()
# Out:
# host_identity_verified
# f    173.428717
# t    174.113331
# Name: price, dtype: float64

# %%
x1.groupby(['bed_type']).mean()['price'].sort_values().dropna()
# Out:
# bed_type
# Airbed            78.675000
# Futon             85.254902
# Couch             99.600000
# Pull-out Sofa    101.612903
# Real Bed         177.203301
# Name: price, dtype: float64

# %%
x1.groupby(['neighbourhood_cleansed']).mean()['price'].sort_values().dropna()
# Out:
# neighbourhood_cleansed
# Mattapan                    75.125000
# Hyde Park                   86.548387
# Dorchester                  91.639405
# Roslindale                  98.428571
# West Roxbury               107.108696
# Allston                    112.307692
# Brighton                   118.767568
# East Boston                119.153333
# Mission Hill               121.967742
# Longwood Medical Area      138.444444
# Jamaica Plain              138.478134
# Roxbury                    146.333333
# South Boston               187.609195
# North End                  195.678322
# Charlestown                198.045045
# South End                  204.349693
# West End                   209.591837
# Fenway                     220.393103
# Beacon Hill                224.443299
# Chinatown                  232.352113
# Downtown                   236.459302
# Back Bay                   240.950331
# Leather District           253.600000
# Bay Village                266.833333
# South Boston Waterfront    306.060241
# Name: price, dtype: float64

# %%
x1.groupby(['host_identity_verified']).mean()['price'].sort_values().dropna()
# Out:
# host_identity_verified
# f    173.428717
# t    174.113331
# Name: price, dtype: float64

# %%
x1.groupby(['host_has_profile_pic']).mean()['price'].sort_values().dropna()
# Out:
# host_has_profile_pic
# f    171.125000
# t    173.932066
# Name: price, dtype: float64

# %%
x1.groupby(['host_is_superhost']).mean()['price'].sort_values().dropna()
# Out:
# host_is_superhost
# f    173.604468
# t    176.434889
# Name: price, dtype: float64

# %% [markdown]
# ### Step4: Prepard data for model building
# Step4.1: Response variables -- Outliner Treatment

# %% [markdown]
# #### Response variable -- Outliner Treatment

# %%
print(x1['price'].describe())
# Out:
# count    3585.000000
# mean      173.925802
# std       148.331321
# min        10.000000
# 25%        85.000000
# 50%       150.000000
# 75%       220.000000
# max      4000.000000
# Name: price, dtype: float64

# %%
# visualizae the price
plt.figure(figsize=(8, 6))
sns.distplot(x1['price'], bins=50, kde=True)
plt.ylabel('Percentage', fontsize=12)
plt.xlabel('Price (dollar)', fontsize=12)
plt.title('Listed Price Distribution', fontsize=14);

# %%
# remove outliers
#Calculate the outliners Q2 + 1.5*IRQ
#Outliner_right= 220+1.5* (220-85) =423
x2 = x1[x1['price'] < 423]
x2.shape
# Out:
# (3461, 54)

# %%
plt.figure(figsize=(8, 6))
sns.distplot(x2['price'], bins=50, kde=True)
plt.ylabel('Percentage', fontsize=12)
plt.xlabel('Price (dollar)', fontsize=12)
plt.title('Listed Price Distribution after remove outlinner', fontsize=14);

# %% [markdown]
# ####  Step4.2: Numarical variables -- Multicollinearity Check

# %%
def calc_vif(X):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

# %%
# Many of the variables are highly corelative
X_VIF = x2.select_dtypes(include=['int64', 'float64']).drop(['price'], axis=1)
calc_vif(X_VIF)
# Out:
# /opt/conda/lib/python3.6/site-packages/statsmodels/stats/outliers_influence.py:167: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#                          variables           VIF
# 0               host_response_rate  7.358004e+01
# 1             host_acceptance_rate  2.510211e+01
# 2              host_listings_count           inf
# 3        host_total_listings_count           inf
# 4               host_verifications  2.326690e+01
# 5                         latitude  1.673951e+06
# 6                        longitude  1.672278e+06
# 7                     accommodates  1.800337e+01
# 8                        bathrooms  9.311378e+00
# 9                         bedrooms  9.997143e+00
# 10                            beds  1.209631e+01
# 11                       amenities  1.465205e+01
# 12                    cleaning_fee  5.840976e+00
# 13                 guests_included  5.072842e+00
# 14                    extra_people  1.732039e+00
# 15                  minimum_nights  1.184553e+00
# 16                  maximum_nights  1.008674e+00
# 17                 availability_30  1.959545e+01
# 18                 availability_60  7.764184e+01
# 19                 availability_90  5.005360e+01
# 20                availability_365  5.209203e+00
# 21               number_of_reviews  2.202773e+00
# 22            review_scores_rating  5.466837e+02
# 23          review_scores_accuracy  3.072908e+02
# 24       review_scores_cleanliness  2.187428e+02
# 25           review_scores_checkin  4.191352e+02
# 26     review_scores_communication  4.749037e+02
# 27          review_scores_location  2.035475e+02
# 28             review_scores_value  3.266703e+02
# 29  calculated_host_listings_count  2.679850e+01
# 30               reviews_per_month  3.469812e+00
# 31                       Superhost  1.346473e+00
# 32                    house_or_not  4.638430e+00
# 33                        host_len  2.902407e+01

# %%
VIF_test_col =[ 'bathrooms','cleaning_fee','guests_included', 'minimum_nights',
               'number_of_reviews','reviews_per_month','host_listings_count',
              'amenities','extra_people','availability_30','accommodates']
X_vif= x2[VIF_test_col]
calc_vif(X_vif)
# Out:
#               variables       VIF
# 0             bathrooms  6.526098
# 1          cleaning_fee  4.164937
# 2       guests_included  4.758028
# 3        minimum_nights  1.169591
# 4     number_of_reviews  1.701724
# 5     reviews_per_month  2.742694
# 6   host_listings_count  1.684013
# 7             amenities  8.238251
# 8          extra_people  1.686947
# 9       availability_30  2.213250
# 10         accommodates  6.710120

# %% [markdown]
# #### Step4.3: Categorical variables -- relative analysis and dummy variables

# %%
clean_data= x2[[ 'property_type', 'room_type','require_guest_phone_verification','bed_type','bathrooms',
       'cleaning_fee','guests_included', 'minimum_nights','number_of_reviews','reviews_per_month',
       'host_listings_count','amenities','extra_people','availability_30','accommodates','price']]
clean_data.head()
# Out:
#          property_type        room_type require_guest_phone_verification  \
# id
# 12147973         House  Entire home/apt                                f
# 3075044      Apartment     Private room                                f
# 6976         Apartment     Private room                                f
# 1436513          House     Private room                                f
# 7651065          House     Private room                                f
#
#           bed_type  bathrooms  cleaning_fee  guests_included  minimum_nights  \
# id
# 12147973  Real Bed        1.5     35.000000                1               2
# 3075044   Real Bed        1.0     10.000000                0               2
# 6976      Real Bed        1.0     68.380145                1               3
# 1436513   Real Bed        1.0     50.000000                2               1
# 7651065   Real Bed        1.5     15.000000                1               2
#
#           number_of_reviews  reviews_per_month  host_listings_count  \
# id
# 12147973                  0           1.970908                    1
# 3075044                  36           1.300000                    1
# 6976                     41           0.470000                    1
# 1436513                   1           1.000000                    1
# 7651065                  29           2.250000                    1
#
#           amenities  extra_people  availability_30  accommodates  price
# id
# 12147973         15           0.0                0             4  250.0
# 3075044          21           0.0               26             2   65.0
# 6976             18          20.0               19             2   65.0
# 1436513          23          25.0                6             4   75.0
# 7651065          14           0.0               13             2   79.0

# %%
#Pull a list of the column names of the categorical variables


def create_dummy_df(df, dummy_na):
    '''
    INPUT:
    df - pandas dataframe with categorical variables you want to dummy
    cat_cols - list of strings that are associated with names of the categorical columns
    dummy_na - Bool holding whether you want to dummy NA vals of categorical columns or not
    
    OUTPUT:
    df - a new dataframe that has the following characteristics:
            1. contains all columns that were not specified as categorical
            2. removes all the original columns in cat_cols
            3. dummy columns for each of the categorical columns in cat_cols
            4. if dummy_na is True - it also contains dummy columns for the NaN values, if fasle fill 00
            5. Use a prefix of the column name with an underscore (_) for separating 
    '''
    cat_vars = df.select_dtypes(include=['object']).copy().columns
    for col in  cat_vars:
        try:
            # for each cat add dummy var, drop original column
            df = pd.concat([df.drop(col, axis=1), pd.get_dummies(df[col], prefix=col, prefix_sep='_', drop_first=True, dummy_na=dummy_na)], axis=1)
        except:
            continue
    return df

# %%
proccessed_data=create_dummy_df(clean_data, dummy_na =True)
proccessed_data.head()
# Out:
#           bathrooms  cleaning_fee  guests_included  minimum_nights  \
# id
# 12147973        1.5     35.000000                1               2
# 3075044         1.0     10.000000                0               2
# 6976            1.0     68.380145                1               3
# 1436513         1.0     50.000000                2               1
# 7651065         1.5     15.000000                1               2
#
#           number_of_reviews  reviews_per_month  host_listings_count  \
# id
# 12147973                  0           1.970908                    1
# 3075044                  36           1.300000                    1
# 6976                     41           0.470000                    1
# 1436513                   1           1.000000                    1
# 7651065                  29           2.250000                    1
#
#           amenities  extra_people  availability_30  accommodates  price  \
# id
# 12147973         15           0.0                0             4  250.0
# 3075044          21           0.0               26             2   65.0
# 6976             18          20.0               19             2   65.0
# 1436513          23          25.0                6             4   75.0
# 7651065          14           0.0               13             2   79.0
#
#           property_type_Bed & Breakfast  property_type_Boat  \
# id
# 12147973                              0                   0
# 3075044                               0                   0
# 6976                                  0                   0
# 1436513                               0                   0
# 7651065                               0                   0
#
#           property_type_Camper/RV  property_type_Condominium  \
# id
# 12147973                        0                          0
# 3075044                         0                          0
# 6976                            0                          0
# 1436513                         0                          0
# 7651065                         0                          0
#
#           property_type_Dorm  property_type_Entire Floor  \
# id
# 12147973                   0                           0
# 3075044                    0                           0
# 6976                       0                           0
# 1436513                    0                           0
# 7651065                    0                           0
#
#           property_type_Guesthouse  property_type_House  property_type_Loft  \
# id
# 12147973                         0                    1                   0
# 3075044                          0                    0                   0
# 6976                             0                    0                   0
# 1436513                          0                    1                   0
# 7651065                          0                    1                   0
#
#           property_type_Other  property_type_Townhouse  property_type_Villa  \
# id
# 12147973                    0                        0                    0
# 3075044                     0                        0                    0
# 6976                        0                        0                    0
# 1436513                     0                        0                    0
# 7651065                     0                        0                    0
#
#           property_type_nan  room_type_Private room  room_type_Shared room  \
# id
# 12147973                  0                       0                      0
# 3075044                   0                       1                      0
# 6976                      0                       1                      0
# 1436513                   0                       1                      0
# 7651065                   0                       1                      0
#
#           room_type_nan  require_guest_phone_verification_t  \
# id
# 12147973              0                                   0
# 3075044               0                                   0
# 6976                  0                                   0
# 1436513               0                                   0
# 7651065               0                                   0
#
#           require_guest_phone_verification_nan  bed_type_Couch  \
# id
# 12147973                                     0               0
# 3075044                                      0               0
# 6976                                         0               0
# 1436513                                      0               0
# 7651065                                      0               0
#
#           bed_type_Futon  bed_type_Pull-out Sofa  bed_type_Real Bed  \
# id
# 12147973               0                       0                  1
# 3075044                0                       0                  1
# 6976                   0                       0                  1
# 1436513                0                       0                  1
# 7651065                0                       0                  1
#
#           bed_type_nan
# id
# 12147973             0
# 3075044              0
# 6976                 0
# 1436513              0
# 7651065              0

# %%
list(proccessed_data.columns)
# Out:
# ['bathrooms',
#  'cleaning_fee',
#  'guests_included',
#  'minimum_nights',
#  'number_of_reviews',
#  'reviews_per_month',
#  'host_listings_count',
#  'amenities',
#  'extra_people',
#  'availability_30',
#  'accommodates',
#  'price',
#  'property_type_Bed & Breakfast',
#  'property_type_Boat',
#  'property_type_Camper/RV',
#  'property_type_Condominium',
#  'property_type_Dorm',
#  'property_type_Entire Floor',
#  'property_type_Guesthouse',
#  'property_type_House',
#  'property_type_Loft',
#  'property_type_Other',
#  'property_type_Townhouse',
#  'property_type_Villa',
#  'property_type_nan',
#  'room_type_Private room',
#  'room_type_Shared room',
#  'room_type_nan',
#  'require_guest_phone_verification_t',
#  'require_guest_phone_verification_nan',
#  'bed_type_Couch',
#  'bed_type_Futon',
#  'bed_type_Pull-out Sofa',
#  'bed_type_Real Bed',
#  'bed_type_nan']

# %% [markdown]
# ### Step5: Build linner regression modle

# %%
#Split into explanatory and response variables
y_raw = np.log2(proccessed_data['price'].astype(int))
y_raw = np.log2(proccessed_data['price'].astype(int))
x_raw= proccessed_data.drop(['price'],axis=1)
#Split into train and test
X1_train, X1_test, y1_train, y1_test = train_test_split(x_raw, y_raw, test_size = .30, random_state=42)
lm_model = LinearRegression(normalize=True) # Instantiate
lm_model.fit(X1_train, y1_train) #Fit

#Predict and score the model
y_test_preds = lm_model.predict(X1_test) 
y_train_preds = lm_model.predict(X1_train) 

#Rsquared and y_test
rsquared_score = r2_score(y1_test, y_test_preds)#r2_score
length_y_test = len(y1_test)#num in y_test

train_score = r2_score(y1_train, y_train_preds)

"The r-squared score for your model was {} on {} values,train set r-squared was{} .".format(rsquared_score, length_y_test,train_score)
# Out:
# 'The r-squared score for your model was 0.6085304822061139 on 1039 values,train set r-squared was0.6102166314393033 .'

# %% [markdown]
# ### Step6: Conduct factor important analysis
# Variables room type,property_type,bed_type,property_type_Bed & Breakfast,require_guest_phone_verification_t,accommodates afact the price most.

# %%
def coef_weights(coefficients, X_train):
    '''
    INPUT:
    coefficients - the coefficients of the linear model 
    X_train - the training data, so the column names can be used
    OUTPUT:
    coefs_df - a dataframe holding the coefficient, estimate, and abs(estimate)
    
    Provides a dataframe that can be used to understand the most influential coefficients
    in a linear model by providing the coefficient estimates along with the name of the 
    variable attached to the coefficient.
    '''
    coefs_df = pd.DataFrame()
    coefs_df['est_int'] = X_train.columns
    coefs_df['coefs'] = lm_model.coef_
    coefs_df['abs_coefs'] = np.abs(lm_model.coef_)
    coefs_df = coefs_df.sort_values('abs_coefs', ascending=False)
    return coefs_df

#Use the function
coef_df = coef_weights(lm_model.coef_, X1_train)

#A quick look at the top results
coef_df.head(20)
# Out:
#                                est_int     coefs  abs_coefs
# 25               room_type_Shared room -1.170502   1.170502
# 20                 property_type_Other  0.910920   0.910920
# 24              room_type_Private room -0.837243   0.837243
# 29                      bed_type_Couch  0.572173   0.572173
# 17            property_type_Guesthouse  0.533257   0.533257
# 15                  property_type_Dorm -0.465546   0.465546
# 22                 property_type_Villa  0.425848   0.425848
# 32                   bed_type_Real Bed  0.388374   0.388374
# 11       property_type_Bed & Breakfast  0.301419   0.301419
# 27  require_guest_phone_verification_t  0.286537   0.286537
# 31              bed_type_Pull-out Sofa  0.241923   0.241923
# 23                   property_type_nan  0.208089   0.208089
# 18                 property_type_House -0.184737   0.184737
# 16          property_type_Entire Floor -0.169804   0.169804
# 21             property_type_Townhouse  0.166263   0.166263
# 19                  property_type_Loft  0.159075   0.159075
# 12                  property_type_Boat  0.147218   0.147218
# 10                        accommodates  0.087702   0.087702
# 30                      bed_type_Futon  0.066833   0.066833
# 14           property_type_Condominium  0.040552   0.040552

# %% [markdown]
# ### Conclusion:
# ### Summary*******************************************************************************************************************
# #### Q1. What's the difference between superhost and regular host?
# #### 1) Do super hosts respond faster than the regular host?
#
#       Yes. The proportion of superhost who respond within an hour is 1.3x higher than the none regular host.
#
# ####  2) Which amenities are more likely to be provided by the superhost vs. the regular host?
#
#       Air Conditioning, shampoo, Fire extinguishers, and Carbon Monoxide Detectors.
#
# ####  3) Do the superhosts' review score is higher than the none superhost?
#       The superhost's satisfaction is higher than the regular host, especially in value and cleanliness.
#
# #### Q2. Is there any bias between the house or other house tpye among the Amenity type ?
#    Yes,houses are more likely have TV, Family/Kid Friendly and Cable TV.
# #### Q3. What's the top 10 expensive neighbourhood?
#    Downtown,Beacon Hill,Back Bay,South End,North End,South Boston Waterfront,Leather District,South Boston,West End,Fenway is the top 10 expensive neighbourhood
# #### Q4.  What's the top 5 factors afact the listing price?
#    Variables room type,property_type,bed_type,property_type_Bed & Breakfast,require_guest_phone_verification_t,accommodates afact the price most
